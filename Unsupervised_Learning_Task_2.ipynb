# %% [markdown]
# #Importing necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
data = pd.read_csv('Iris.csv')

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# #Checking general information about data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
data.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %% [markdown]
# #Checking General Distribution of the features

# %% [markdown]
# ***
# **1) SepalLengthCm**
# ***

# %%
fig,ax = plt.subplots(3, 1, sharex=False)
fig.set_size_inches(10,10)
sns.distplot(data['SepalLengthCm'], ax=ax[0] , color='orange')
sns.boxplot(data['SepalLengthCm'] , ax=ax[1] , color='seagreen')
sns.violinplot(data['SepalLengthCm'] , ax=ax[2])
plt.show()

# %% [markdown]
# ***
# **2) SepalWidthCm**
# ***

# %%
fig,ax = plt.subplots(3, 1, sharex=False)
fig.set_size_inches(10,10)
sns.distplot(data['SepalWidthCm'], ax=ax[0] , color='orange')
sns.boxplot(data['SepalWidthCm'] , ax=ax[1] , color='seagreen')
sns.violinplot(data['SepalWidthCm'] , ax=ax[2])
plt.show()

# %% [markdown]
# ****
# **3) Petal Length**
# ****

# %%
fig,ax = plt.subplots(3, 1, sharex=False)
fig.set_size_inches(10,10)
sns.distplot(data['PetalLengthCm'], ax=ax[0] , color='orange')
sns.boxplot(data['PetalLengthCm'] , ax=ax[1] , color='seagreen')
sns.violinplot(data['PetalLengthCm'] , ax=ax[2])
plt.show()

# %% [markdown]
# ***
# **4)Petal Width**
# ***

# %%
fig,ax = plt.subplots(3, 1, sharex=False)
fig.set_size_inches(10,10)
sns.distplot(data['PetalWidthCm'], ax=ax[0] , color='orange')
sns.boxplot(data['PetalWidthCm'] , ax=ax[1] , color='seagreen')
sns.violinplot(data['PetalWidthCm'] , ax=ax[2])
plt.show()

# %% [markdown]
# #Univariate Analysis

# %%
fig ,ax = plt.subplots(1 ,2 , sharex=False)
fig.set_size_inches(18,8)
ax[0].set_title('voilinplot' , fontsize=16)
ax[1].set_title('boxplot' , fontsize=16)
sns.violinplot(x='Species' , y='SepalLengthCm' , data=data , ax=ax[0])
sns.boxplot(x='Species' , y='SepalLengthCm' , data=data, ax=ax[1])

plt.show()

# %%
fig ,ax = plt.subplots(1 ,2 , sharex=False)
fig.set_size_inches(18,8)
ax[0].set_title('voilinplot' , fontsize=16)
ax[1].set_title('boxplot' , fontsize=16)
sns.violinplot(x='Species' , y='SepalWidthCm' , data=data , ax=ax[0])
sns.boxplot(x='Species' , y='SepalWidthCm' , data=data, ax=ax[1])

plt.show()

# %%
fig ,ax = plt.subplots(1 ,2 , sharex=False)
fig.set_size_inches(18,8)
ax[0].set_title('voilinplot' , fontsize=16)
ax[1].set_title('boxplot' , fontsize=16)
sns.violinplot(x='Species' , y='PetalLengthCm' , data=data , ax=ax[0])
sns.boxplot(x='Species' , y='PetalLengthCm' , data=data, ax=ax[1])

plt.show()

# %%
fig ,ax = plt.subplots(1 ,2 , sharex=False)
fig.set_size_inches(18,8)
ax[0].set_title('voilinplot' , fontsize=16)
ax[1].set_title('boxplot' , fontsize=16)
sns.violinplot(x='Species' , y='PetalWidthCm' , data=data , ax=ax[0])
sns.boxplot(x='Species' , y='PetalWidthCm' , data=data, ax=ax[1])

plt.show()

# %% [markdown]
# #Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

LE = LabelEncoder()

data['Species_Coded']=LE.fit_transform(data['Species'])

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  ...  PetalWidthCm      Species Species_Coded
# 0   1            5.1           3.5  ...           0.2  Iris-setosa             0
# 1   2            4.9           3.0  ...           0.2  Iris-setosa             0
# 2   3            4.7           3.2  ...           0.2  Iris-setosa             0
# 3   4            4.6           3.1  ...           0.2  Iris-setosa             0
# 4   5            5.0           3.6  ...           0.2  Iris-setosa             0
#
# [5 rows x 7 columns]

# %% [markdown]
# #Scaling the data using StandardScalar

# %%
from sklearn.preprocessing import MinMaxScaler
data2 = data.drop(['Species' ,'Species_Coded' ,'Id'] , axis=1)
data2.head()
Sc = MinMaxScaler()
Arr = Sc.fit_transform(data2)
data2 = pd.DataFrame(data=Arr , columns=data2.columns)
data2['Species'] = data['Species']
data2.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0       0.222222      0.625000       0.067797      0.041667  Iris-setosa
# 1       0.166667      0.416667       0.067797      0.041667  Iris-setosa
# 2       0.111111      0.500000       0.050847      0.041667  Iris-setosa
# 3       0.083333      0.458333       0.084746      0.041667  Iris-setosa
# 4       0.194444      0.666667       0.067797      0.041667  Iris-setosa

# %% [markdown]
# #Data Distribution

# %%
plt.figure(figsize=(20,10))
sns.pairplot(data=data2 , hue='Species')
plt.show()

# %% [markdown]
# #Finding the value using KElbowVisualiser

# %%
from yellowbrick.cluster import KElbowVisualizer 
from sklearn.cluster import KMeans
model1 = KMeans() 
visualizer = KElbowVisualizer(model1, k=(1,10)) 
visualizer.fit(data2.iloc[:,[0,1,2,3]])
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# KElbowVisualizer(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x7fd9b64b9b38>,
#                  k=None, metric=None, model=None, timings=True)

# %% [markdown]
# #Selecting the number of clusters with silhouette analysis on KMeans clustering

# %% [markdown]
# 1.   **silhouette coefficient has a range of [-1, 1]**
# 2.   **Silhouette coefficients near +1 indicate that the sample is far away from the neighboring clusters. A value of 0 indicates that the sample is on or very close to the decision boundary between two neighboring clusters and negative values indicate that those samples might have been assigned to the wrong cluster.**

# %%
from yellowbrick.cluster import SilhouetteVisualizer
model2 = KMeans(3)
visualizer = SilhouetteVisualizer(model2)

visualizer.fit(data2.iloc[:,[0,1,2,3]])
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# SilhouetteVisualizer(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x7fd9b5d15fd0>,
#                      model=None)

# %% [markdown]
# #n_clustering = 3

# %%
X_data = data2.iloc[:,[0,1,2,3]]
kmean = KMeans(n_clusters=3)
kmean.fit(X_data)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
X_data['Clusters'] = kmean.predict(X_data)
X_data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Clusters
# 0       0.222222      0.625000       0.067797      0.041667         1
# 1       0.166667      0.416667       0.067797      0.041667         1
# 2       0.111111      0.500000       0.050847      0.041667         1
# 3       0.083333      0.458333       0.084746      0.041667         1
# 4       0.194444      0.666667       0.067797      0.041667         1

# %% [markdown]
# #Visualizing clusters

# %% [markdown]
# ***
# SepalLengthCm V/s SepalWidthCm
# ***

# %%
colors = {0:'red' , 1:'blue' ,2:'magenta'}
plt.figure(figsize=(10,8))
plt.scatter(X_data['SepalLengthCm'] , X_data['SepalWidthCm'] , c=X_data['Clusters'].apply(lambda x:colors[x]))
plt.scatter(kmean.cluster_centers_[:,0],kmean.cluster_centers_[:,1] , marker='*' , color='black'  , s=250)
plt.show()

# %% [markdown]
# ***
# SepalLengthCm V/s PetalLengthCm
# ***

# %%
colors = {0:'red' , 1:'blue' ,2:'magenta'}
plt.figure(figsize=(10,8))
plt.scatter(X_data['SepalLengthCm'] , X_data['PetalLengthCm'] , c=X_data['Clusters'].apply(lambda x:colors[x]))
plt.scatter(kmean.cluster_centers_[:,0],kmean.cluster_centers_[:,2] , marker='*' , color='black'  , s=250)
plt.show()

# %%
kmean.cluster_centers_
# 0: SepalLength
# 1: SepalWidth
# 2: PetalLength
# 3: PetalWidth
# Out:
# array([[0.44125683, 0.30737705, 0.57571548, 0.54918033],
#        [0.19611111, 0.59083333, 0.07864407, 0.06      ],
#        [0.70726496, 0.4508547 , 0.79704476, 0.82478632]])

# %% [markdown]
# ***
# SepalLengthCm V/s PetalWidthCm
# ***

# %%
colors = {0:'red' , 1:'blue' ,2:'magenta'}
plt.figure(figsize=(10,8))
plt.scatter(X_data['SepalLengthCm'] , X_data['PetalWidthCm'] , c=X_data['Clusters'].apply(lambda x:colors[x]))
plt.scatter(kmean.cluster_centers_[:,0],kmean.cluster_centers_[:,3] , marker='*' , color='black'  , s=250)
plt.show()

# %% [markdown]
# ***
#
#
# SepalWidthCm V/s PetalLengthCm
#
#
# ***

# %%
colors = {0:'red' , 1:'blue' ,2:'magenta'}
plt.figure(figsize=(10,8))
plt.scatter(X_data['SepalWidthCm'] , X_data['PetalLengthCm'] , c=X_data['Clusters'].apply(lambda x:colors[x]))
plt.scatter(kmean.cluster_centers_[:,1],kmean.cluster_centers_[:,2] , marker='*' , color='black'  , s=250)
plt.show()

# %% [markdown]
# ***
# SepalWidthCm V/s PetalWidthCm
# ***

# %%
colors = {0:'red' , 1:'blue' ,2:'magenta'}
plt.figure(figsize=(10,8))
plt.scatter(X_data['SepalWidthCm'] , X_data['PetalWidthCm'] , c=X_data['Clusters'].apply(lambda x:colors[x]))
plt.scatter(kmean.cluster_centers_[:,1],kmean.cluster_centers_[:,3] , marker='*' , color='black'  , s=250)
plt.show()

# %% [markdown]
# ***
# PetalWidthCm V/s PetalLengthCm
# ***

# %%
colors = {0:'red' , 1:'blue' ,2:'magenta'}
plt.figure(figsize=(10,8))
plt.scatter(X_data['PetalWidthCm'] , X_data['PetalLengthCm'] , c=X_data['Clusters'].apply(lambda x:colors[x]))
plt.scatter(kmean.cluster_centers_[:,2],kmean.cluster_centers_[:,3] , marker='*' , color='black'  , s=250)
plt.show()

# %% [markdown]
# #Evaluation of the Model

# %%
from sklearn.metrics import confusion_matrix
Cm =  confusion_matrix(data['Species_Coded'],X_data['Clusters'])
sns.heatmap(Cm, annot=True, fmt="d", cmap="Blues")

# %% [markdown]
# #maximizing the sum of diagonal

# %%
from sklearn.utils.linear_assignment_ import linear_assignment
import numpy as np

def _make_cost_m(cm):
    s = np.max(cm)
    return (- cm + s)

indexes = linear_assignment(_make_cost_m(Cm))
js = [e[1] for e in sorted(indexes, key=lambda x: x[0])]
cm2 = Cm[:, js]
sns.heatmap(cm2, annot=True, fmt="d", cmap="Blues")
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:22: FutureWarning: The linear_assignment_ module is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)

# %% [markdown]
# #Accuracy of the model

# %%
Accuracy = np.trace(cm2) / np.sum(cm2)
Accuracy
# Out:
# 0.8866666666666667

# %%
from coclust.evaluation.external import accuracy
score  = accuracy(data['Species_Coded'] , X_data['Clusters'])
score
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/linear_assignment_.py:128: FutureWarning: The linear_assignment function is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   FutureWarning)
# 0.8866666666666667
